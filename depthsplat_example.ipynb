# %%
# !git clone https://github.com/munholy/depthsplat
# Out:
# Cloning into 'depthsplat'...
# remote: Enumerating objects: 215, done.
# remote: Counting objects: 100% (215/215), done.
# remote: Compressing objects: 100% (171/171), done.
# remote: Total 215 (delta 49), reused 185 (delta 34), pack-reused 0 (from 0)
# Receiving objects: 100% (215/215), 2.25 MiB | 1.10 MiB/s, done.
# Resolving deltas: 100% (49/49), done.

# %%
# !pip install -r depthsplat/requirements.txt
# Out:
# WARNING: The directory '/root/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 1)) (0.38.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 2)) (4.66.1)
# Requirement already satisfied: pytorch_lightning in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 3)) (2.4.0)
# Requirement already satisfied: black in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 4)) (24.10.0)
# Requirement already satisfied: ruff in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 5)) (0.7.2)
# Requirement already satisfied: hydra-core in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: jaxtyping in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 7)) (0.2.34)
# Requirement already satisfied: beartype in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 8)) (0.19.0)
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 9)) (0.16.2)
# Requirement already satisfied: einops in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 10)) (0.8.0)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 11)) (0.4.6)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 12)) (0.24.0)
# Requirement already satisfied: colorspacious in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 13)) (1.1.2)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 14)) (3.9.2)
# Requirement already satisfied: moviepy in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 15)) (1.0.3)
# Requirement already satisfied: imageio in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 16)) (2.33.1)
# Requirement already satisfied: dacite in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 18)) (1.8.1)
# Requirement already satisfied: lpips in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 19)) (0.1.4)
# Requirement already satisfied: e3nn in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 20)) (0.5.3)
# Requirement already satisfied: plyfile in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 21)) (1.1)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 22)) (0.9.0)
# Requirement already satisfied: svg.py in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 23)) (1.5.0)
# Requirement already satisfied: opencv-python>=4.8.1.78 in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 24)) (4.9.0.80)
# Requirement already satisfied: sk-video in /opt/conda/lib/python3.10/site-packages (from -r depthsplat/requirements.txt (line 25)) (1.1.10)
# Requirement already satisfied: numpy>=1.21.2 in /opt/conda/lib/python3.10/site-packages (from opencv-python>=4.8.1.78->-r depthsplat/requirements.txt (line 24)) (1.26.4)
# Requirement already satisfied: tomli>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from black->-r depthsplat/requirements.txt (line 4)) (2.0.2)
# Requirement already satisfied: platformdirs>=2 in /opt/conda/lib/python3.10/site-packages (from black->-r depthsplat/requirements.txt (line 4)) (4.3.6)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from black->-r depthsplat/requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: click>=8.0.0 in /opt/conda/lib/python3.10/site-packages (from black->-r depthsplat/requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: pathspec>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from black->-r depthsplat/requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from black->-r depthsplat/requirements.txt (line 4)) (4.12.2)
# Requirement already satisfied: packaging>=22.0 in /opt/conda/lib/python3.10/site-packages (from black->-r depthsplat/requirements.txt (line 4)) (24.1)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from e3nn->-r depthsplat/requirements.txt (line 20)) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from e3nn->-r depthsplat/requirements.txt (line 20)) (2.4.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from e3nn->-r depthsplat/requirements.txt (line 20)) (1.13.3)
# Requirement already satisfied: opt-einsum-fx>=0.1.4 in /opt/conda/lib/python3.10/site-packages (from e3nn->-r depthsplat/requirements.txt (line 20)) (0.1.4)
# Requirement already satisfied: opt-einsum in /opt/conda/lib/python3.10/site-packages (from opt-einsum-fx>=0.1.4->e3nn->-r depthsplat/requirements.txt (line 20)) (3.4.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->e3nn->-r depthsplat/requirements.txt (line 20)) (3.16.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->e3nn->-r depthsplat/requirements.txt (line 20)) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->e3nn->-r depthsplat/requirements.txt (line 20)) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->e3nn->-r depthsplat/requirements.txt (line 20)) (2024.10.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /opt/conda/lib/python3.10/site-packages (from hydra-core->-r depthsplat/requirements.txt (line 6)) (4.9.3)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /opt/conda/lib/python3.10/site-packages (from hydra-core->-r depthsplat/requirements.txt (line 6)) (2.3.0)
# Requirement already satisfied: PyYAML>=5.1.0 in /opt/conda/lib/python3.10/site-packages (from omegaconf<2.4,>=2.2->hydra-core->-r depthsplat/requirements.txt (line 6)) (6.0.2)
# Requirement already satisfied: pillow>=8.3.2 in /opt/conda/lib/python3.10/site-packages (from imageio->-r depthsplat/requirements.txt (line 16)) (10.2.0)
# Requirement already satisfied: typeguard==2.13.3 in /opt/conda/lib/python3.10/site-packages (from jaxtyping->-r depthsplat/requirements.txt (line 7)) (2.13.3)
# Requirement already satisfied: torchvision>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from lpips->-r depthsplat/requirements.txt (line 19)) (0.19.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->-r depthsplat/requirements.txt (line 14)) (1.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->-r depthsplat/requirements.txt (line 14)) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->-r depthsplat/requirements.txt (line 14)) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->-r depthsplat/requirements.txt (line 14)) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->-r depthsplat/requirements.txt (line 14)) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->-r depthsplat/requirements.txt (line 14)) (4.54.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->-r depthsplat/requirements.txt (line 14)) (1.16.0)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from moviepy->-r depthsplat/requirements.txt (line 15)) (0.4.9)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /opt/conda/lib/python3.10/site-packages (from moviepy->-r depthsplat/requirements.txt (line 15)) (4.4.2)
# Requirement already satisfied: proglog<=1.0.0 in /opt/conda/lib/python3.10/site-packages (from moviepy->-r depthsplat/requirements.txt (line 15)) (0.1.10)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from moviepy->-r depthsplat/requirements.txt (line 15)) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from imageio-ffmpeg>=0.2.0->moviepy->-r depthsplat/requirements.txt (line 15)) (65.5.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0,>=2.8.1->moviepy->-r depthsplat/requirements.txt (line 15)) (2.2.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0,>=2.8.1->moviepy->-r depthsplat/requirements.txt (line 15)) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0,>=2.8.1->moviepy->-r depthsplat/requirements.txt (line 15)) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0,>=2.8.1->moviepy->-r depthsplat/requirements.txt (line 15)) (2024.8.30)
# Requirement already satisfied: torchmetrics>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from pytorch_lightning->-r depthsplat/requirements.txt (line 3)) (1.5.1)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from pytorch_lightning->-r depthsplat/requirements.txt (line 3)) (0.11.8)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.10/site-packages (from fsspec->torch>=1.8.0->e3nn->-r depthsplat/requirements.txt (line 20)) (3.10.10)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch>=1.8.0->e3nn->-r depthsplat/requirements.txt (line 20)) (24.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch>=1.8.0->e3nn->-r depthsplat/requirements.txt (line 20)) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch>=1.8.0->e3nn->-r depthsplat/requirements.txt (line 20)) (1.5.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch>=1.8.0->e3nn->-r depthsplat/requirements.txt (line 20)) (1.17.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch>=1.8.0->e3nn->-r depthsplat/requirements.txt (line 20)) (6.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch>=1.8.0->e3nn->-r depthsplat/requirements.txt (line 20)) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch>=1.8.0->e3nn->-r depthsplat/requirements.txt (line 20)) (1.3.1)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from yarl<2.0,>=1.12.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch>=1.8.0->e3nn->-r depthsplat/requirements.txt (line 20)) (0.2.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image->-r depthsplat/requirements.txt (line 12)) (2024.9.20)
# Requirement already satisfied: lazy-loader>=0.4 in /opt/conda/lib/python3.10/site-packages (from scikit-image->-r depthsplat/requirements.txt (line 12)) (0.4)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb->-r depthsplat/requirements.txt (line 9)) (6.1.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb->-r depthsplat/requirements.txt (line 9)) (0.4.0)
# Requirement already satisfied: appdirs>=1.4.3 in /opt/conda/lib/python3.10/site-packages (from wandb->-r depthsplat/requirements.txt (line 9)) (1.4.4)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb->-r depthsplat/requirements.txt (line 9)) (2.17.0)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb->-r depthsplat/requirements.txt (line 9)) (1.3.3)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb->-r depthsplat/requirements.txt (line 9)) (4.25.2)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb->-r depthsplat/requirements.txt (line 9)) (3.1.43)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb->-r depthsplat/requirements.txt (line 9)) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->-r depthsplat/requirements.txt (line 9)) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->e3nn->-r depthsplat/requirements.txt (line 20)) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->e3nn->-r depthsplat/requirements.txt (line 20)) (1.3.0)

# %%
# !mkdir depthsplat/pretrained
# !wget -P depthsplat/pretrained https://huggingface.co/haofeixu/depthsplat/resolve/main/depthsplat-gs-small-re10k-256x256-49b2d15c.pth
# Out:
# mkdir: cannot create directory ‘depthsplat/pretrained’: File exists
# --2024-11-04 07:39:03--  https://huggingface.co/haofeixu/depthsplat/resolve/main/depthsplat-gs-small-re10k-256x256-49b2d15c.pth
# Resolving huggingface.co (huggingface.co)... 3.168.178.101, 3.168.178.31, 3.168.178.58, ...
# Connecting to huggingface.co (huggingface.co)|3.168.178.101|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs-us-1.hf.co/repos/e2/4e/e24e7686e9c27778b01e5c45cf39b8fe8e3b18ca04a96fc220da07a8c9c27d6d/49b2d15cada75e1bb1b3a243567a7e0b52fa98bf4bc1d2719a99b73d4bf9b9ae?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27depthsplat-gs-small-re10k-256x256-49b2d15c.pth%3B+filename%3D%22depthsplat-gs-small-re10k-256x256-49b2d15c.pth%22%3B&Expires=1730965143&Policy=&Signature=qGQZPcOcnn4t7QzG-Vzu3xQ3-s%7Eh8W1bCLbDLDltUtfs%7EOEUgxmW0thbDJTFi0vrg%7E2k4QDkHaBa0n34-NINwSaEkNM28YUuIZGZoxy8zZa8KJNqJLokENofnk3SUQefmluJlHhO%7E0MmriR%7EOVS9U2cU3vLK0bDI5hU9SdvhhryYdIsVyncgRI4J5QXF6rafpjQ5mWLtxTFX95xsEK%7ET5hzV0ct%7E-rrb7y58gabwYcDXmyGC3-k5dq26aM94VCTIcNSMYB1E2yZoggNUPXPFksym7x2-mhZTF7AHu72OfWcuglS4mWppEaXnL43pV8whnl%7EpeCcq92OyR2heCetqSA__&Key-Pair-Id=K24J24Z295AEI9 [following]
# --2024-11-04 07:39:03--  https://cdn-lfs-us-1.hf.co/repos/e2/4e/e24e7686e9c27778b01e5c45cf39b8fe8e3b18ca04a96fc220da07a8c9c27d6d/49b2d15cada75e1bb1b3a243567a7e0b52fa98bf4bc1d2719a99b73d4bf9b9ae?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27depthsplat-gs-small-re10k-256x256-49b2d15c.pth%3B+filename%3D%22depthsplat-gs-small-re10k-256x256-49b2d15c.pth%22%3B&Expires=1730965143&Policy=&Signature=qGQZPcOcnn4t7QzG-Vzu3xQ3-s%7Eh8W1bCLbDLDltUtfs%7EOEUgxmW0thbDJTFi0vrg%7E2k4QDkHaBa0n34-NINwSaEkNM28YUuIZGZoxy8zZa8KJNqJLokENofnk3SUQefmluJlHhO%7E0MmriR%7EOVS9U2cU3vLK0bDI5hU9SdvhhryYdIsVyncgRI4J5QXF6rafpjQ5mWLtxTFX95xsEK%7ET5hzV0ct%7E-rrb7y58gabwYcDXmyGC3-k5dq26aM94VCTIcNSMYB1E2yZoggNUPXPFksym7x2-mhZTF7AHu72OfWcuglS4mWppEaXnL43pV8whnl%7EpeCcq92OyR2heCetqSA__&Key-Pair-Id=K24J24Z295AEI9
# Resolving cdn-lfs-us-1.hf.co (cdn-lfs-us-1.hf.co)... 18.64.8.45, 18.64.8.120, 18.64.8.16, ...
# Connecting to cdn-lfs-us-1.hf.co (cdn-lfs-us-1.hf.co)|18.64.8.45|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149341264 (142M) [binary/octet-stream]
# Saving to: ‘depthsplat/pretrained/depthsplat-gs-small-re10k-256x256-49b2d15c.pth.1’
#
# depthsplat-gs-small 100%[===================>] 142.42M  41.0MB/s    in 3.5s
#
# 2024-11-04 07:39:07 (41.0 MB/s) - ‘depthsplat/pretrained/depthsplat-gs-small-re10k-256x256-49b2d15c.pth.1’ saved [149341264/149341264]

# %%
import os
os.chdir(os.path.join(os.getcwd(),'depthsplat'))
print(os.getcwd())
# Out:
# /root/mun/depthsplat/depthsplat

# %%
import torch
import torch.nn.functional as F
from PIL import Image
import numpy as np
import torchvision.transforms as tf
from einops import repeat
from omegaconf import OmegaConf

from src.model.encoder.encoder_depthsplat import EncoderDepthSplat
from src.config import load_typed_config
from src.model.encoder import EncoderCfg
import rerun as rr

# %%
def process_images(image_paths, target_shape):
    """Process input images into proper tensor format"""
    images = []
    for path in image_paths:
        img = Image.open(path)
        img = tf.ToTensor()(img)
        if img.shape[-2:] != target_shape:
            img = F.interpolate(img.unsqueeze(0), size=target_shape, 
                                mode='bilinear', align_corners=True).squeeze(0)
        images.append(img)
    
    return torch.stack(images)

class DepthSplatDepthPredictor:
    def __init__(self, checkpoint_path):
        """
        Args:
            checkpoint_path: Path to the pretrained depth model checkpoint
        """


        # Load base config
        encoder_cfg = OmegaConf.load("config/model/encoder/depthsplat.yaml")
        
        encoder_cfg['num_depth_candidates'] = 128
        encoder_cfg['costvolume_unet_feat_dim'] = 128
        encoder_cfg['costvolume_unet_channel_mult'] = [1,1,1]
        encoder_cfg['costvolume_unet_attn_res'] = [4]
        encoder_cfg['gaussians_per_pixel'] = 1
        encoder_cfg['depth_unet_feat_dim'] = 32
        encoder_cfg['depth_unet_attn_res'] = [16]
        encoder_cfg['depth_unet_channel_mult'] = [1,1,1,1,1]

        if 'large' in checkpoint_path:
            ## large
            encoder_cfg['num_scales']=2
            encoder_cfg['upsample_factor']=2
            encoder_cfg['lowest_feature_resolution']=4
            encoder_cfg['monodepth_vit_type']='vitl'
            encoder_cfg['gaussian_regressor_channels']=64
            encoder_cfg['color_large_unet']=True
            encoder_cfg['feature_upsampler_channels']=128
        elif 'base' in checkpoint_path:
            ## base
            encoder_cfg['num_scales'] = 2
            encoder_cfg['upsample_factor'] = 2
            encoder_cfg['lowest_feature_resolution'] = 4
            encoder_cfg['monodepth_vit_type'] = "vitb"
            encoder_cfg['color_large_unet'] = True
            encoder_cfg['feature_upsampler_channels'] = 128
            encoder_cfg['gaussian_regressor_channels'] = 32
        else:
            ## small
            assert('small' in checkpoint_path)
            encoder_cfg['upsample_factor']=4
            encoder_cfg['lowest_feature_resolution']=4
            encoder_cfg['gaussian_regressor_channels']=16
            encoder_cfg['feature_upsampler_channels']=64


        encoder_cfg['return_depth'] = True
        encoder_cfg['train_depth_only'] = True


        cfg_encoder = load_typed_config(encoder_cfg, EncoderCfg)

        self.encoder = EncoderDepthSplat(cfg_encoder)
        
        checkpoint = torch.load(checkpoint_path, map_location='cpu')
        
        new_state_dict = {}
        for key in checkpoint['state_dict']:
            new_key = key.removeprefix('encoder.')
            new_state_dict[new_key] = checkpoint['state_dict'][key].clone().detach()
        self.encoder.load_state_dict(new_state_dict, strict = False)
        
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.encoder = self.encoder.to(self.device)
        self.encoder.eval()
        

    def predict(self, images, intrinsics, extrinsics, translation_scaling = 5.0, logging = False):
        # Initialize rerun logging
        
        
        # Process inputs
        images = images.to(self.device)
        intrinsics = intrinsics.to(self.device)
        extrinsics = extrinsics.to(self.device)

        extrinsics[...,:3,3:] *= translation_scaling

        num_views = images.size(1)
        # Log input images
        if logging:
            for idx in range(num_views):
                
                # Log camera position and orientation
                cam_extrinsics = extrinsics[0, idx].cpu().numpy()
                R = cam_extrinsics[:3, :3]
                T = cam_extrinsics[:3, 3] / translation_scaling

                rr.log(f"world/camera_{idx}", 
                    rr.Transform3D(translation=T,
                                    mat3x3=R, axis_length= 0.1))

        # Create near and far tensors
        near = repeat(torch.tensor(0.5, dtype=torch.float32, device=self.device), "-> v", v=num_views).unsqueeze(0)
        far = repeat(torch.tensor(100, dtype=torch.float32, device=self.device), "-> v", v=num_views).unsqueeze(0)

        context = {
            'image': images,
            'extrinsics': extrinsics,
            'intrinsics': intrinsics,
            'near': near,
            'far': far
        }

        # Forward pass
        with torch.inference_mode(), torch.autocast("cuda", dtype=torch.bfloat16):
            

            output = self.encoder(context, global_step=0, deterministic=False)
            pred_depths = output["depths"]

            pred_depths = pred_depths / translation_scaling

        if logging:
            # Visualize depth maps and point clouds
            for idx, depth in enumerate(pred_depths[0]):
                # Log depth map
                if logging:
                    rr.log(f"world/camera_{idx}/depth", rr.DepthImage(depth.cpu(), meter = 1.0))
                
                # Create point cloud from depth
                h, w = depth.shape
                y, x = torch.meshgrid(torch.arange(h) / float(h), torch.arange(w) / float(w), indexing='ij')
                pixels = torch.stack([x, y], dim=-1).float().to(self.device)
                
                # Get camera intrinsics
                fx = intrinsics[0, idx, 0, 0].item()
                fy = intrinsics[0, idx, 1, 1].item()
                cx = intrinsics[0, idx, 0, 2].item()
                cy = intrinsics[0, idx, 1, 2].item()
                
                # Convert to 3D points
                Z = depth.reshape(-1)
                X = (pixels[..., 0].reshape(-1) - cx) * Z / fx
                Y = (pixels[..., 1].reshape(-1) - cy) * Z / fy
                points = torch.stack([X, Y, Z], dim=-1)
                
                # Transform points to world coordinates
                # points_homogeneous = torch.cat([points, torch.ones_like(points[:, :1])], dim=-1)
                R = extrinsics[0, idx, :3, :3]
                T = extrinsics[0, idx, :3, 3] / translation_scaling
                world_points = (R @ points.T).T.add(T.view(1,3)).cpu()
                
                # Get colors from original image
                colors = images[0,idx].permute(1,2,0).cpu().numpy().reshape(-1, 3)
                
                # Log point cloud
                
                rr.log(f"world/points_{idx}", 
                    rr.Points3D(world_points[:, :3],
                                colors=colors,
                                radii=0.002))

        return pred_depths

# %%
rr.init("depthsplat_depth_prediction")

model_path = "pretrained/depthsplat-gs-small-re10k-256x256-49b2d15c.pth"
predictor = DepthSplatDepthPredictor(model_path)

image_paths = ['../sample/checker_left.png', '../sample/checker_right.png']

# Camera poses


R0 = torch.tensor([[-0.9859, -0.0948, -0.1377],
        [ 0.0489, -0.9512,  0.3045],
        [-0.1599,  0.2935,  0.9425]])
T0 = torch.tensor([ 0.2313, -0.3366, -0.4551])


ext1 = torch.eye(4)
ext1[:3,:3] = R0.T
ext1[:3,3] = T0

R1 = torch.tensor([[-0.9574,  0.1549,  0.2438],
        [-0.0665, -0.9396,  0.3359],
        [ 0.2811,  0.3053,  0.9098]])
T1 = torch.tensor([ 0.0512, -0.3418, -0.4622])

ext2 = torch.eye(4)
ext2[:3,:3] = R1.T
ext2[:3,3] = T1

extrinsics = torch.stack([ext1, ext2])[None]

# Camera intrinsics
target_shape = (480 , 640)
intrinsics = torch.tensor([386, 0, 320, 0, 386, 240, 0, 0, 1]).view(3,3).float()[None].repeat(2,1,1)[None]

##### Normalized intrinsics !!!! #####
intrinsics[:,:,0] = intrinsics[:,:,0] / target_shape[1]
intrinsics[:,:,1] = intrinsics[:,:,1] / target_shape[0]


images = process_images(image_paths, target_shape)
images = images[None]

# Get depth predictions
print(images.shape)
print(intrinsics.shape)
print(extrinsics.shape)
depth_maps = predictor.predict(images, intrinsics, extrinsics, logging=True)

rr.notebook_show(width=1600, height=800)
# Out:
# Using cache found in /root/.cache/torch/hub/facebookresearch_dinov2_main
# torch.Size([1, 2, 3, 480, 640])
# torch.Size([1, 2, 3, 3])
# torch.Size([1, 2, 4, 4])
# Viewer()
